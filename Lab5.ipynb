# %%
from collections import Counter, defaultdict
from itertools import combinations
import pandas as pd
import numpy as np
import operator
import math
import itertools
from sklearn.feature_extraction import DictVectorizer
from sklearn import preprocessing, tree
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

# %%
train = pd.read_csv('/train.csv')
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
test = pd.read_csv('/test.csv')
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
gender_submission = pd.read_csv('/gender_submission.csv')
gender_submission
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
print(train.isna().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print(test.isna().sum())
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
def fun(x):
  if x < 1: return 0
  if x < 12: return 1
  if x < 18: return 2
  if x < 60: return 3
  return 4
jus = train.copy()
jus['Age'] = jus['Age'].fillna(100).apply(fun)
jus.groupby('Age')['Survived'].mean()
# Out:
# Age
# 0    1.000000
# 1    0.524590
# 2    0.488889
# 3    0.386087
# 4    0.290640
# Name: Survived, dtype: float64

# %%
test = pd.merge(test, gender_submission, on='PassengerId')
test
# Out:
#     PassengerId  Pclass                                               Name  \
# 0           904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 1           906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 2           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 3           918       1                       Ostby, Miss. Helene Ragnhild
# 4           920       1                            Brady, Mr. John Bertram
# ..          ...     ...                                                ...
# 82         1296       1                       Frauenthal, Mr. Isaac Gerald
# 83         1297       2       Nourney, Mr. Alfred (Baron von Drachstedt")"
# 84         1299       1                         Widener, Mr. George Dunton
# 85         1303       1    Minahan, Mrs. William Edward (Lillian E Thorpe)
# 86         1306       1                       Oliva y Ocana, Dona. Fermina
#
# ...

# %%
train = train = train.dropna(subset=['Age', 'Pclass', 'Sex'])
train['Sex'] = train['Sex'].map({'male': 0, 'female': 1})
test = test.dropna()
vec = DictVectorizer()
le = preprocessing.LabelEncoder()
x = train[['Age', 'Pclass', 'Sex']].to_dict('records')
y = le.fit_transform(test['Survived'])
x = vec.fit_transform(x).toarray()
clf = tree.DecisionTreeClassifier(max_depth=3, random_state=42)
clf = clf.fit(x, y)
y_pred = clf.predict(x)
accuracy = accuracy_score(y, y_pred)
accuracy
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1971376161.py in <cell line: 0>()
#       6 x = train[['Age', 'Pclass', 'Sex']].to_dict('records')
#       7 y = le.fit_transform(test['Survived'])
# ----> 8 x = vec.fit_transform(x).toarray()
#       9 clf = tree.DecisionTreeClassifier(max_depth=3, random_state=42)
#      10 clf = clf.fit(x, y)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
# ...
